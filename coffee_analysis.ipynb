# %%
import pandas as pd

# %%
# The dataframe related to coffee production will be uploaded and checked in order to see if data is completed or it must be cleaned
df_production = pd.read_csv('Coffee_production.csv')
df_production.head()
# Out:
#                             Country      Coffee type       1990/91  \
# 0                            Angola  Robusta/Arabica  3.000000e+06
# 1  Bolivia (Plurinational State of)          Arabica  7.380000e+06
# 2                            Brazil  Arabica/Robusta  1.637160e+09
# 3                           Burundi  Arabica/Robusta  2.922000e+07
# 4                           Ecuador  Arabica/Robusta  9.024000e+07
#
#         1991/92       1992/93       1993/94       1994/95       1995/96  \
# 0  4.740000e+06  4.680000e+06  1.980000e+06  4.620000e+06  3.720000e+06
# 1  6.240000e+06  7.200000e+06  3.060000e+06  7.020000e+06  8.520000e+06
# 2  1.637580e+09  2.076180e+09  1.690020e+09  1.691520e+09  1.083600e+09
# 3  4.002000e+07  3.720000e+07  2.358000e+07  3.984000e+07  2.604000e+07
# 4  1.274400e+08  7.110000e+07  1.241400e+08  1.425600e+08  1.132800e+08
#
#         1996/97       1997/98  ...       2011/12       2012/13       2013/14  \
# ...

# %%
df_production.dtypes
# Out:
# Country              object
# Coffee type          object
# 1990/91             float64
# 1991/92             float64
# 1992/93             float64
# 1993/94             float64
# 1994/95             float64
# 1995/96             float64
# 1996/97             float64
# 1997/98             float64
# 1998/99             float64
# 1999/00             float64
# 2000/01             float64
# 2001/02             float64
# 2002/03             float64
# 2003/04             float64
# 2004/05             float64
# 2005/06             float64
# 2006/07             float64
# 2007/08             float64
# 2008/09             float64
# 2009/10             float64
# 2010/11             float64
# 2011/12             float64
# 2012/13             float64
# 2013/14             float64
# 2014/15             float64
# 2015/16             float64
# 2016/17             float64
# 2017/18             float64
# 2018/19             float64
# 2019/20             float64
# Total_production    float64
# ...

# %%
df_production.describe()
# Out:
#             1990/91       1991/92       1992/93       1993/94       1994/95  \
# count  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   1.017055e+08  1.104753e+08  1.074775e+08  1.001007e+08  1.017971e+08
# std    2.510875e+08  2.668466e+08  3.022180e+08  2.489344e+08  2.510328e+08
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    2.430000e+06  3.900000e+06  2.640000e+06  2.130000e+06  2.610000e+06
# 50%    2.766000e+07  2.778000e+07  3.000000e+07  2.652000e+07  2.436000e+07
# 75%    9.216000e+07  9.720000e+07  9.234000e+07  9.486000e+07  1.153200e+08
# max    1.637160e+09  1.637580e+09  2.076180e+09  1.690020e+09  1.691520e+09
#
#             1995/96       1996/97       1997/98       1998/99       1999/00  \
# count  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   9.525927e+07  1.127029e+08  1.089676e+08  1.187629e+08  1.433280e+08
# ...

# %%
df_production.shape
# Out:
# (55, 33)

# %%
#check if there are NaN values
df_production.isna().count()
# Out:
# Country             55
# Coffee type         55
# 1990/91             55
# 1991/92             55
# 1992/93             55
# 1993/94             55
# 1994/95             55
# 1995/96             55
# 1996/97             55
# 1997/98             55
# 1998/99             55
# 1999/00             55
# 2000/01             55
# 2001/02             55
# 2002/03             55
# 2003/04             55
# 2004/05             55
# 2005/06             55
# 2006/07             55
# 2007/08             55
# 2008/09             55
# 2009/10             55
# 2010/11             55
# 2011/12             55
# 2012/13             55
# 2013/14             55
# 2014/15             55
# 2015/16             55
# 2016/17             55
# 2017/18             55
# 2018/19             55
# 2019/20             55
# Total_production    55
# dtype: int64

# %%
import matplotlib.pyplot as plt

# Filter data for Bolivia
bolivia_data = df_production[df_production['Country'] == 'Bolivia (Plurinational State of)']

# Extract columns representing years
year_columns = bolivia_data.columns[2:-1]

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(year_columns, bolivia_data.iloc[0, 2:-1].values, marker='o')
plt.title('Coffee Production Trend in Bolivia Over the Years')
plt.xlabel('Year')
plt.ylabel('Production (Kg)')
plt.grid(True)
plt.show()

# %%
pip install country_converter
# Out:
# ...
# WARNING: You are using pip version 21.1.2; however, version 23.3.2 is available.
# You should consider upgrading via the 'C:\Users\marco\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import matplotlib.pyplot as plt
import country_converter as coco

# Add 'Continent' column to the DataFrame
df_production['Continent'] = df_production['Country'].apply(lambda x: coco.CountryConverter().convert(names=x, to='continent'))

# Filter data for countries in America
america_data = df_production[df_production['Continent'] == 'America']

# Extract columns representing years
year_columns = america_data.columns[2:-2]

# Plotting for countries in America
plt.figure(figsize=(18, 12))
for country, row in america_data.iterrows():
    plt.plot(year_columns, row[2:-2].values, marker='o', label=str(country))

plt.title('Coffee Production Trend in America')
plt.xlabel('Year')
plt.ylabel('Production (Kg)')
plt.xticks(rotation=90)  # Rotate x-axis labels by 90 degrees
plt.legend(labels=america_data['Country'], loc='center left', bbox_to_anchor=(1, 0.5), title='Country', fontsize='small')
plt.grid(True)
plt.show()

# %%
#The production plot along the years for Bolivia
# Filter data for Bolivia
bolivia_data = df_production[df_production['Country'] == 'Bolivia (Plurinational State of)']

# Extract columns representing years
year_columns = bolivia_data.columns[2:-2]

# Plotting for Bolivia
plt.figure(figsize=(12, 6))
plt.plot(year_columns, bolivia_data.iloc[0, 2:-2].values, marker='o')
plt.title('Coffee Production Trend in Bolivia')
plt.xlabel('Year')
plt.ylabel('Production (Kg)')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
# Filter data for Bolivia, Peru, Colombia, and Ecuador
selected_countries = ['Bolivia (Plurinational State of)', 'Peru', 'Colombia', 'Ecuador']
selected_data = df_production[df_production['Country'].isin(selected_countries)]

# Sort selected data based on maximum production value
selected_data = selected_data.loc[selected_data.iloc[:, 2:-2].max(axis=1).sort_values(ascending=False).index]

# Extract columns representing years
year_columns = selected_data.columns[2:-2]

# Define colors for each country
colors = ['blue', 'green', 'red', 'purple']

# Plotting for selected countries
plt.figure(figsize=(12, 6))
for idx, (country, row) in enumerate(selected_data.iterrows()):
    plt.plot(year_columns, row[2:-2].values, marker='o', label=country, color=colors[idx])

# Create a custom legend for selected countries
legend_labels = selected_data['Country']
plt.legend(loc='center left', bbox_to_anchor=(1.05, 0.5), title='Country', fontsize='small', labels=legend_labels)

plt.title('Coffee Production Trend (Bolivia, Peru, Colombia, Ecuador)')
plt.xlabel('Year')
plt.ylabel('Production (Kg)')
plt.xticks(rotation=90)  # Rotate x-axis labels by 90 degrees
plt.grid(True)
plt.tight_layout()  # Ensures the plot layout is tight
plt.show()

# %%
#Top 10 coffee producers in the world
top_producers = df_production.sort_values(by='Total_production', ascending=False)
top_producers=top_producers.head(10)
top_producers
# Out:
#       Country      Coffee type       1990/91       1991/92       1992/93  \
# 2      Brazil  Arabica/Robusta  1.637160e+09  1.637580e+09  2.076180e+09
# 53   Viet Nam  Robusta/Arabica  7.860000e+07  8.628000e+07  1.404000e+08
# 23   Colombia          Arabica  8.637600e+08  1.078800e+09  8.968200e+08
# 5   Indonesia  Robusta/Arabica  4.464600e+08  5.095800e+08  3.341400e+08
# 29   Ethiopia          Arabica  1.745400e+08  1.755000e+08  1.095000e+08
# 36      India  Robusta/Arabica  1.697400e+08  1.800000e+08  1.693800e+08
# 41     Mexico  Arabica/Robusta  2.804400e+08  2.836200e+08  2.040600e+08
# 32  Guatemala  Arabica/Robusta  1.962600e+08  2.098200e+08  2.590800e+08
# 35   Honduras          Arabica  9.408000e+07  1.393200e+08  1.150800e+08
# 51     Uganda  Robusta/Arabica  1.173000e+08  1.252800e+08  1.311000e+08
#
#          1993/94       1994/95       1995/96       1996/97       1997/98  ...  \
# 2   1.690020e+09  1.691520e+09  1.083600e+09  1.751820e+09  1.568880e+09  ...
# ...

# %%
# Plotting bar plot
plt.figure(figsize=(12, 6))
plt.bar(top_producers['Country'], top_producers['Total_production'], color='green')
plt.title('Top 10 Coffee Producers in the World')
plt.xlabel('Country')
plt.ylabel('Total Production (Kg)')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Ensures the plot layout is tight
plt.show()

# %%
# Assuming df_production is your original DataFrame

# Combine 'Arabica/Robusta' and 'Robusta/Arabica' into a single category 'Arabica/Robusta'
df_production['Coffee type'] = df_production['Coffee type'].replace({'Robusta/Arabica': 'Arabica/Robusta'})

# Calculate total production for each 'Coffee type'
total_production_by_type = df_production.groupby('Coffee type')['Total_production'].sum()

# Calculate the percentage of total production for each 'Coffee type'
percentage_by_type = (total_production_by_type / total_production_by_type.sum()) * 100

# Display the result
print(percentage_by_type)
# Out:
# Coffee type
# Arabica            25.679919
# Arabica/Robusta    70.945422
# Robusta             3.374659
# Name: Total_production, dtype: float64

# %%
#This means that almost 71% of the coffee producer countries, produce both types Arabica and Robusta, while 25% produce only Arabica and only 3.37% produces only robusta.add()

# %%
import country_converter as coco

# Add 'Continent' column to the DataFrame
df_production['Continent'] = df_production['Country'].apply(lambda x: coco.CountryConverter().convert(names=x, to='continent'))

# Calculate total production per continent
total_production_by_continent = df_production.groupby('Continent')['Total_production'].sum().sort_values(ascending=False)

# Display the result
print(total_production_by_continent)
# Out:
# Continent
# America    1.392145e+11
# Asia       5.589792e+10
# Africa     2.881932e+10
# Oceania    1.803120e+09
# Name: Total_production, dtype: float64

# %%
#which one is the country from oceania?
oceania_countries = df_production[df_production['Continent'] == 'Oceania']['Country'].unique()

# Display the list of Oceania countries
print(oceania_countries)
# Out:
# ['Papua New Guinea']

# %%
df_production
# Out:
#                              Country      Coffee type       1990/91  \
# 0                             Angola  Arabica/Robusta  3.000000e+06
# 1   Bolivia (Plurinational State of)          Arabica  7.380000e+06
# 2                             Brazil  Arabica/Robusta  1.637160e+09
# 3                            Burundi  Arabica/Robusta  2.922000e+07
# 4                            Ecuador  Arabica/Robusta  9.024000e+07
# 5                          Indonesia  Arabica/Robusta  4.464600e+08
# 6                         Madagascar          Robusta  5.892000e+07
# 7                             Malawi          Arabica  6.300000e+06
# 8                   Papua New Guinea  Arabica/Robusta  5.778000e+07
# 9                           Paraguay          Arabica  7.860000e+06
# 10                              Peru          Arabica  5.622000e+07
# 11                            Rwanda          Arabica  3.210000e+07
# 12                       Timor-Leste          Arabica  0.000000e+00
# ...

# %%
## How was the coffee production last year available? (2019/20)

# Select the last year column
last_year_column = df_production.columns[-2]

# Sort the DataFrame by total production in the last year
sorted_df = df_production.sort_values(by=last_year_column, ascending=False)

# Plotting
plt.figure(figsize=(14, 8))
plt.bar(sorted_df['Country'], sorted_df[last_year_column], color='skyblue', edgecolor='black')

plt.title(f'Coffee Production by Country (Stacked) in {last_year_column}')
plt.xlabel('Country')
plt.ylabel('Total Production (Kg)')
plt.xticks(rotation=90, ha='right')  # Rotate x-axis labels for better readability
plt.tight_layout()  # Ensures the plot layout is tight
plt.show()

# %%
#who were the top 5 coffee producers for each year?
# Extract columns representing years
year_columns = df_production.columns[2:-1]

# List to store top 5 producers for each year
top_producers_by_year = []

# Loop through each year
for year in year_columns:
    # Sort DataFrame by production for the current year in descending order
    sorted_df = df_production.sort_values(by=year, ascending=False)
    
    # Extract the top 5 producers for the current year
    top_5_producers = sorted_df[['Country', year]].head(5).values.tolist()
    
    # Append the result to the list
    top_producers_by_year.append((year, top_5_producers))

# Display the result
for year, top_producers in top_producers_by_year:
    print(f"Top 5 Producers in {year}:\n")
    for producer in top_producers:
        print(f"{producer[0]}: {producer[1]:,.0f} Kg")
    print("\n")
# Out:
# Top 5 Producers in 1990/91:
#
# Brazil: 1,637,160,000 Kg
# Colombia: 863,760,000 Kg
# Indonesia: 446,460,000 Kg
# Mexico: 280,440,000 Kg
# Guatemala: 196,260,000 Kg
#
#
# Top 5 Producers in 1991/92:
#
# Brazil: 1,637,580,000 Kg
# Colombia: 1,078,800,000 Kg
# Indonesia: 509,580,000 Kg
# Mexico: 283,620,000 Kg
# Côte d'Ivoire: 247,740,000 Kg
#
#
# Top 5 Producers in 1992/93:
#
# Brazil: 2,076,180,000 Kg
# Colombia: 896,820,000 Kg
# Indonesia: 334,140,000 Kg
# Guatemala: 259,080,000 Kg
# Mexico: 204,060,000 Kg
#
#
# Top 5 Producers in 1993/94:
#
# Brazil: 1,690,020,000 Kg
# Colombia: 685,320,000 Kg
# Indonesia: 404,580,000 Kg
# Mexico: 301,380,000 Kg
# Guatemala: 212,160,000 Kg
#
#
# Top 5 Producers in 1994/95:
#
# Brazil: 1,691,520,000 Kg
# Colombia: 777,840,000 Kg
# Indonesia: 322,080,000 Kg
# Mexico: 249,540,000 Kg
# Guatemala: 227,220,000 Kg
#
#
# Top 5 Producers in 1995/96:
#
# Brazil: 1,083,600,000 Kg
# Colombia: 776,280,000 Kg
# Mexico: 318,000,000 Kg
# Indonesia: 274,380,000 Kg
# ...

# %%
# Extract columns representing years
year_columns = df_production.columns[2:-1]

# List to store top 5 producers for each year
top_producers_by_year = []

# Loop through each year
for year in year_columns:
    # Sort DataFrame by production for the current year in descending order
    sorted_df = df_production.sort_values(by=year, ascending=False)
    
    # Extract the top 5 producers for the current year
    top_5_producers = sorted_df[['Country', year]].head(5)
    
    # Plotting
    plt.figure(figsize=(12, 6))
    plt.bar(top_5_producers['Country'], top_5_producers[year], color='skyblue', edgecolor='black')
    plt.title(f'Top 5 Coffee Producers in {year}')
    plt.xlabel('Country')
    plt.ylabel('Total Production (Kg)')
    plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
    plt.tight_layout()  # Ensures the plot layout is tight
    plt.show()

# %%
#It is clear that Brazil is the world's top coffee producer ranking first in the analyzed years, while in the last years Vietnam is consolidated as the
#second producer surpassing Colombia, which now alternates with Indonesia as the 3rd and 4th top producer country
#For 5th place, there is a similar battle between Honduras and Ethiopia.
